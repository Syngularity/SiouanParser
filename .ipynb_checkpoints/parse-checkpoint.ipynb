# %% [markdown]
# # Siouan Parser v1.0

# %%
#Imports

import nltk
nltk.download('punkt')
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
import itertools
import threading
import time
import sys
import re
import os
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\alexm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **Important Variables**

# %%
#Auto high frequency detection value (%)
stopFreq = 1

#Stop Characters ignored in sources
stopChars = "(,.;?\-:)"

sourceDir = "sources"
os.chdir(sourceDir)

#First run - Install NLTK Dependancy
firstRun = False

source = ""

# %% [markdown]
# **Function Definitions**

# %%
#An animation function to show that sources are still being parsed
def animate(action, stop):
    for c in itertools.cycle(['|', '/', '-', '\\']):
        if stop():
            break
        sys.stdout.write('\r' + action +' ' + c)
        sys.stdout.flush()
        time.sleep(0.1)
    sys.stdout.flush()
    sys.stdout.write('\rComplete!\n')

# %% [markdown]
# **Join all sources from the 'sources' directory into one**

# %%
print ("Parsing Source <" + sourceDir + "> directory...")

for filename in os.listdir(os.getcwd()):
    with open(os.path.join(os.getcwd(), filename), encoding="utf8") as f:
        source = source + f.read()
        print ("\tProcessed: " + filename + "\n")
print (str(len(os.listdir(os.getcwd()))) + " File(s) Processed.")
# Out:
# Parsing Source <sources> directory...
# 	Processed: bible.txt
#
# 1 File(s) Processed.

# %% [markdown]
# **Prase source files into an NLTK readable format**

# %%
stopThread = False
t = threading.Thread(target=animate, args=('Parsing', lambda : stopThread,))
t.start()

#Clean up input
parsed = ''.join([i for i in source if not i.isdigit()]) #Remove numbers
parsed = parsed.replace('\n', ' ').replace('\r', '') #Remove newline
parsed = re.sub(' +', ' ', parsed) #Remove extra spaces
parsed = re.sub('[' + stopChars + ']', '', parsed) #Remove stop characters
parsed = parsed.lower() #Set to all lowercase

stopThread = True
# Out:
# Complete!

# %% [markdown]
# **Run NLTK**

# %%
stopThread = False
t = threading.Thread(target=animate, args=('NLTK', lambda : stopThread,))
t.start()

#Begin NLTK Processing
tokens = word_tokenize(parsed)
fdist = FreqDist(tokens)

stopThread = True
time.sleep(1.0)

freqFrame = pd.DataFrame(fdist.most_common(100), columns=['words', 'occurance'])

frequency = []
for i in fdist.most_common(100):
    frequency.append(round(fdist.freq(i[0])*100,2))
freqFrame['frequency %'] = frequency

display(freqFrame)
# Out:
# Complete!
#          words  occurance  frequency %
# 0          kin      50567         6.88
# 1           qa      37410         5.09
# 2          kta      21102         2.87
# 3           he      19074         2.60
# 4        unkan      11392         1.55
# 5           en      10721         1.46
# 6          śni      10132         1.38
# 7           on       8699         1.18
# 8          cin       8257         1.12
# 9         hena       7206         0.98
# 10        taku       6400         0.87
# 11      jehowa       6126         0.83
# 12           |       6058         0.82
# 13     etanhan       5838         0.79
# 14         kte       5637         0.77
# 15         wan       5188         0.71
# 16     wicasta       4813         0.66
# 17        ekta       4698         0.64
# 18        tuka       4654         0.63
# 19      owasin       4611         0.63
# 20         iye       4506         0.61
# 21          wo       3851         0.52
# 22       hecen       3509         0.48
# 23          ce       3252         0.44
# 24        ohna       3071         0.42
# 25          un       3039         0.41
# 26        heon       3012         0.41
# 27       hehan       2942         0.40
# 28       wakan       2898         0.39
# 29        tuwe       2667         0.36
# 30        tawa       2655         0.36
# 31       cinca       2630         0.36
# 32         eya       2529         0.34
# 33      anpetu       2523         0.34
# 34           e       2519         0.34
# 35       oyate       2513         0.34
# 36      israel       2421         0.33
# 37       nakun       2420         0.33
# 38          pi       2408         0.33
# 39          wi       2367         0.32
# 40          na       2362         0.32
# 41        tona       2325         0.32
# 42          wa       2306         0.31
# 43         han       2306         0.31
# 44         ece       2282         0.31
# 45         qon       2247         0.31
# 46          ye       2166         0.29
# 47          ca       2152         0.29
# 48      kinhan       2069         0.28
# 49  wakantanka       2068         0.28
# 50          po       2053         0.28
# 51          de       1986         0.27
# 52        akan       1960         0.27
# 53        tipi       1939         0.26
# 54        yapi       1917         0.26
# 55      makoce       1892         0.26
# 56     itancan       1844         0.25
# 57  wicowoyake       1836         0.25
# 58      iyecen       1834         0.25
# 59          ya       1829         0.25
# 60          ga       1771         0.24
# 61        niye       1723         0.23
# 62           i       1690         0.23
# 63          ça       1688         0.23
# 64        miye       1595         0.22
# 65       tanka       1578         0.21
# 66         hee       1498         0.20
# 67       waste       1441         0.20
# 68   cinhintku       1376         0.19
# 69        maka       1364         0.19
# 70        wica       1343         0.18
# 71        nape       1308         0.18
# 72         can       1288         0.18
# 73          ni       1279         0.17
# 74          ta       1258         0.17
# 75        heya       1257         0.17
# 76      otonwe       1245         0.17
# 77     wicaśta       1244         0.17
# 78      heciya       1243         0.17
# 79        kici       1240         0.17
# 80        econ       1194         0.16
# 81    wikcemna       1144         0.16
# 82     iyececa       1142         0.16
# 83        juda       1131         0.15
# 84       sanpa       1124         0.15
# 85      itokam       1103         0.15
# 86      yatapi       1089         0.15
# 87       wanji       1088         0.15
# 88          ti       1086         0.15
# 89       nonpa       1074         0.15
# 90       dawid       1063         0.14
# 91      tokeca       1055         0.14
# 92      nitawa       1054         0.14
# 93       jesus       1054         0.14
# 94          ka       1040         0.14
# 95          ko        965         0.13
# 96         sni        965         0.13
# 97          pa        963         0.13
# 98        unpi        951         0.13
# 99           u        913         0.12
